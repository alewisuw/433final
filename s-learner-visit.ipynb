# %%
import numpy as np
import optuna
import pandas as pd
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, average_precision_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

# %%
# Cell 2: Load datasets and define key columns
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

outcome_col = "visit"
treatment_col = "treatment"

exclude_from_features = {outcome_col, "conversion", "exposure"}
feature_cols = [c for c in train_df.columns if c not in exclude_from_features]
X_train = train_df[feature_cols].copy()
y_train = train_df[outcome_col].astype(int)
X_test = test_df[feature_cols].copy()
y_test = test_df[outcome_col].astype(int)

print("Train rows:", len(train_df), "| Test rows:", len(test_df))
# Out:
# Train rows: 582540 | Test rows: 200000

# %%
# Cell 3: Train LightGBM S-learner with 50-trial Optuna search (optimize AUPRC)
numeric_cols = X_train.select_dtypes(include=[np.number, "bool"]).columns.tolist()
categorical_cols = [c for c in X_train.columns if c not in numeric_cols]

# Use pandas categorical dtype so LightGBM can handle categorical features natively.
for col in categorical_cols:
    combined = pd.concat([X_train[col], X_test[col]], axis=0).astype("string")
    categories = pd.Index(combined.dropna().unique())
    X_train[col] = pd.Categorical(X_train[col].astype("string"), categories=categories)
    X_test[col] = pd.Categorical(X_test[col].astype("string"), categories=categories)

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42,
    stratify=y_train,
    )

def objective(trial):
    params = {
        "objective": "binary",
        "n_estimators": trial.suggest_int("n_estimators", 100, 600),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 16, 128),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 200),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
        "random_state": 42,
        "n_jobs": -1,
        "verbosity": -1,
    }
    model = LGBMClassifier(**params)
    model.fit(X_tr, y_tr, categorical_feature=categorical_cols)
    val_proba = model.predict_proba(X_val)[:, 1]
    return average_precision_score(y_val, val_proba)

study = optuna.create_study(direction="maximize", study_name="s_learner_visit_auprc")
study.optimize(objective, n_trials=50, show_progress_bar=False)

best_params = study.best_params.copy()
best_params.update({"objective": "binary", "random_state": 42, "n_jobs": -1, "verbosity": -1})

s_learner = LGBMClassifier(**best_params)
s_learner.fit(X_train, y_train, categorical_feature=categorical_cols)

print(f"Best validation AUPRC: {study.best_value:.4f}")
print("LightGBM S-learner trained using best Optuna trial on full training data.")
# Out:
# [I 2026-04-07 17:33:44,564] A new study created in memory with name: s_learner_visit_auprc
# [I 2026-04-07 17:33:48,245] Trial 0 finished with value: 0.5063173826777445 and parameters: {'n_estimators': 158, 'learning_rate': 0.16893485472168207, 'num_leaves': 30, 'max_depth': 8, 'min_child_samples': 80, 'subsample': 0.6898848660640683, 'colsample_bytree': 0.7142575841712653, 'reg_alpha': 2.555857382871488, 'reg_lambda': 0.22558523596787525}. Best is trial 0 with value: 0.5063173826777445.
# [I 2026-04-07 17:33:56,360] Trial 1 finished with value: 0.4949301966103754 and parameters: {'n_estimators': 485, 'learning_rate': 0.1918902180710938, 'num_leaves': 102, 'max_depth': 6, 'min_child_samples': 80, 'subsample': 0.6401951567469407, 'colsample_bytree': 0.9835441027547264, 'reg_alpha': 0.0007136294459288363, 'reg_lambda': 1.6646750827156616e-05}. Best is trial 0 with value: 0.5063173826777445.
# [I 2026-04-07 17:34:02,218] Trial 2 finished with value: 0.511072222594579 and parameters: {'n_estimators': 486, 'learning_rate': 0.019807992931584632, 'num_leaves': 103, 'max_depth': 3, 'min_child_samples': 143, 'subsample': 0.6496678120584067, 'colsample_bytree': 0.999809927905563, 'reg_alpha': 0.2606073137309324, 'reg_lambda': 0.4668445258051202}. Best is trial 2 with value: 0.511072222594579.
# [I 2026-04-07 17:34:07,205] Trial 3 finished with value: 0.5114631357162521 and parameters: {'n_estimators': 350, 'learning_rate': 0.07499033325436817, 'num_leaves': 47, 'max_depth': 3, 'min_child_samples': 58, 'subsample': 0.8153505943746355, 'colsample_bytree': 0.813160309060048, 'reg_alpha': 0.005212037047132993, 'reg_lambda': 0.12869534624105264}. Best is trial 3 with value: 0.5114631357162521.
# [I 2026-04-07 17:34:21,617] Trial 4 finished with value: 0.5103711416126396 and parameters: {'n_estimators': 541, 'learning_rate': 0.03974901861712089, 'num_leaves': 98, 'max_depth': 8, 'min_child_samples': 34, 'subsample': 0.7036399348558002, 'colsample_bytree': 0.7112454265774083, 'reg_alpha': 8.18143671877309, 'reg_lambda': 0.0005115118611673166}. Best is trial 3 with value: 0.5114631357162521.
# [I 2026-04-07 17:34:25,590] Trial 5 finished with value: 0.5032938999248554 and parameters: {'n_estimators': 131, 'learning_rate': 0.1018640250269244, 'num_leaves': 123, 'max_depth': 12, 'min_child_samples': 66, 'subsample': 0.952299808656185, 'colsample_bytree': 0.9487512909468303, 'reg_alpha': 9.75847544844568e-07, 'reg_lambda': 6.812730967422402e-08}. Best is trial 3 with value: 0.5114631357162521.
# [I 2026-04-07 17:34:31,419] Trial 6 finished with value: 0.5080209766950669 and parameters: {'n_estimators': 293, 'learning_rate': 0.10437447895631113, 'num_leaves': 42, 'max_depth': 7, 'min_child_samples': 46, 'subsample': 0.8942735232889061, 'colsample_bytree': 0.7241658312957104, 'reg_alpha': 0.47083083067854836, 'reg_lambda': 2.9354684046838604}. Best is trial 3 with value: 0.5114631357162521.
# [I 2026-04-07 17:34:36,967] Trial 7 finished with value: 0.5113160131735931 and parameters: {'n_estimators': 208, 'learning_rate': 0.050789540564831995, 'num_leaves': 74, 'max_depth': 12, 'min_child_samples': 172, 'subsample': 0.754020686686087, 'colsample_bytree': 0.7419337247516062, 'reg_alpha': 0.0008496775099454911, 'reg_lambda': 5.9539047473143525e-08}. Best is trial 3 with value: 0.5114631357162521.
# [I 2026-04-07 17:34:40,367] Trial 8 finished with value: 0.5144371381278133 and parameters: {'n_estimators': 152, 'learning_rate': 0.041164769411738314, 'num_leaves': 45, 'max_depth': 11, 'min_child_samples': 117, 'subsample': 0.7920321507200881, 'colsample_bytree': 0.913143738340596, 'reg_alpha': 0.020835709240856898, 'reg_lambda': 0.32712498305887566}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:34:44,532] Trial 9 finished with value: 0.5114269450035818 and parameters: {'n_estimators': 318, 'learning_rate': 0.0742962393081279, 'num_leaves': 61, 'max_depth': 4, 'min_child_samples': 144, 'subsample': 0.7607028258521604, 'colsample_bytree': 0.9338107470881898, 'reg_alpha': 0.05218392610603172, 'reg_lambda': 4.3257185042359313e-05}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:34:49,398] Trial 10 finished with value: 0.5122866326097338 and parameters: {'n_estimators': 240, 'learning_rate': 0.010000057367159646, 'num_leaves': 22, 'max_depth': 10, 'min_child_samples': 116, 'subsample': 0.8488301714889889, 'colsample_bytree': 0.8483151927578869, 'reg_alpha': 7.734563978368158e-06, 'reg_lambda': 0.004323964901791561}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:34:53,296] Trial 11 finished with value: 0.5109340779828464 and parameters: {'n_estimators': 230, 'learning_rate': 0.01054273927188984, 'num_leaves': 17, 'max_depth': 10, 'min_child_samples': 125, 'subsample': 0.8434818607292816, 'colsample_bytree': 0.8589005005976393, 'reg_alpha': 3.087141290916878e-06, 'reg_lambda': 0.005129016248018209}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:34:55,787] Trial 12 finished with value: 0.5107869846503433 and parameters: {'n_estimators': 112, 'learning_rate': 0.021055850012892792, 'num_leaves': 17, 'max_depth': 10, 'min_child_samples': 104, 'subsample': 0.8900692691898741, 'colsample_bytree': 0.6124840432305013, 'reg_alpha': 2.0732701446270464e-08, 'reg_lambda': 0.007160343744143518}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:35:01,325] Trial 13 finished with value: 0.5142776227650936 and parameters: {'n_estimators': 250, 'learning_rate': 0.012262051752896538, 'num_leaves': 42, 'max_depth': 10, 'min_child_samples': 107, 'subsample': 0.9655610473933168, 'colsample_bytree': 0.8698258016562678, 'reg_alpha': 1.6492089196880944e-05, 'reg_lambda': 6.934216886348982}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:35:09,948] Trial 14 finished with value: 0.5135238903762173 and parameters: {'n_estimators': 389, 'learning_rate': 0.02305829870496075, 'num_leaves': 66, 'max_depth': 11, 'min_child_samples': 193, 'subsample': 0.9892778909763208, 'colsample_bytree': 0.9105528547225739, 'reg_alpha': 3.794096160870321e-05, 'reg_lambda': 5.904012765686722}. Best is trial 8 with value: 0.5144371381278133.
# [I 2026-04-07 17:35:14,373] Trial 15 finished with value: 0.5147458588393444 and parameters: {'n_estimators': 178, 'learning_rate': 0.0313723994903178, 'num_leaves': 47, 'max_depth': 9, 'min_child_samples': 96, 'subsample': 0.9278251200829265, 'colsample_bytree': 0.8904553986738428, 'reg_alpha': 0.015500060004274412, 'reg_lambda': 4.30378024961954}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:18,865] Trial 16 finished with value: 0.5122052007744186 and parameters: {'n_estimators': 180, 'learning_rate': 0.03532584053408451, 'num_leaves': 83, 'max_depth': 9, 'min_child_samples': 18, 'subsample': 0.9118731596160877, 'colsample_bytree': 0.8958941058588192, 'reg_alpha': 0.008943715097127354, 'reg_lambda': 0.02318509065716144}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:21,430] Trial 17 finished with value: 0.5130726813756944 and parameters: {'n_estimators': 100, 'learning_rate': 0.029314214043025765, 'num_leaves': 53, 'max_depth': 6, 'min_child_samples': 88, 'subsample': 0.7697275106213528, 'colsample_bytree': 0.8077567184225001, 'reg_alpha': 0.009120197319019505, 'reg_lambda': 0.5346390614416575}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:28,628] Trial 18 finished with value: 0.5096766828313029 and parameters: {'n_estimators': 411, 'learning_rate': 0.053454283497248976, 'num_leaves': 34, 'max_depth': 11, 'min_child_samples': 150, 'subsample': 0.8168772329795856, 'colsample_bytree': 0.9544844100693815, 'reg_alpha': 0.07034739448334396, 'reg_lambda': 0.0003332531925290993}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:32,757] Trial 19 finished with value: 0.5141831963000272 and parameters: {'n_estimators': 177, 'learning_rate': 0.02779884839362538, 'num_leaves': 56, 'max_depth': 9, 'min_child_samples': 131, 'subsample': 0.9296556919547395, 'colsample_bytree': 0.8959600848961062, 'reg_alpha': 0.00021306859079496483, 'reg_lambda': 1.122327507894001e-06}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:41,840] Trial 20 finished with value: 0.5146211384758709 and parameters: {'n_estimators': 303, 'learning_rate': 0.01724725535397115, 'num_leaves': 77, 'max_depth': 7, 'min_child_samples': 95, 'subsample': 0.8634577930471423, 'colsample_bytree': 0.7693700324826792, 'reg_alpha': 0.8005687241268351, 'reg_lambda': 0.07802075240267456}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:49,712] Trial 21 finished with value: 0.5141644795057283 and parameters: {'n_estimators': 299, 'learning_rate': 0.01583017228315885, 'num_leaves': 81, 'max_depth': 6, 'min_child_samples': 106, 'subsample': 0.8632147711291459, 'colsample_bytree': 0.7680920880453949, 'reg_alpha': 0.8399161463265412, 'reg_lambda': 0.046206449257215926}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:35:56,924] Trial 22 finished with value: 0.5145520408611094 and parameters: {'n_estimators': 273, 'learning_rate': 0.015786128828116062, 'num_leaves': 90, 'max_depth': 7, 'min_child_samples': 93, 'subsample': 0.7823743078672896, 'colsample_bytree': 0.773809778257033, 'reg_alpha': 0.031116454731927517, 'reg_lambda': 1.1960432832873868}. Best is trial 15 with value: 0.5147458588393444.
# [I 2026-04-07 17:36:03,978] Trial 23 finished with value: 0.515140849293108 and parameters: {'n_estimators': 272, 'learning_rate': 0.015190519023906592, 'num_leaves': 77, 'max_depth': 7, 'min_child_samples': 91, 'subsample': 0.715378211003999, 'colsample_bytree': 0.6611979614414394, 'reg_alpha': 0.1381275614611942, 'reg_lambda': 1.0222061802909996}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:11,923] Trial 24 finished with value: 0.5128830732076481 and parameters: {'n_estimators': 383, 'learning_rate': 0.013576313123982435, 'num_leaves': 72, 'max_depth': 5, 'min_child_samples': 68, 'subsample': 0.7238281991655671, 'colsample_bytree': 0.6651464302473553, 'reg_alpha': 0.17819489698589702, 'reg_lambda': 0.05092093252651307}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:21,946] Trial 25 finished with value: 0.5149070665399658 and parameters: {'n_estimators': 339, 'learning_rate': 0.017914326643698585, 'num_leaves': 113, 'max_depth': 8, 'min_child_samples': 96, 'subsample': 0.8742795053146224, 'colsample_bytree': 0.6749085828132275, 'reg_alpha': 2.3988438756691406, 'reg_lambda': 2.16008388409919}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:31,888] Trial 26 finished with value: 0.5137208392286715 and parameters: {'n_estimators': 342, 'learning_rate': 0.02850336358678202, 'num_leaves': 124, 'max_depth': 9, 'min_child_samples': 52, 'subsample': 0.9346487484629415, 'colsample_bytree': 0.605147008164193, 'reg_alpha': 4.421412281612987, 'reg_lambda': 3.3574808618372414}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:38,695] Trial 27 finished with value: 0.5145455204224321 and parameters: {'n_estimators': 202, 'learning_rate': 0.023654964302628784, 'num_leaves': 114, 'max_depth': 8, 'min_child_samples': 76, 'subsample': 0.6130997668625362, 'colsample_bytree': 0.6647203501668447, 'reg_alpha': 0.0026335059773807457, 'reg_lambda': 1.3389178882166577}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:47,314] Trial 28 finished with value: 0.5136024649401048 and parameters: {'n_estimators': 460, 'learning_rate': 0.013184129283712175, 'num_leaves': 112, 'max_depth': 5, 'min_child_samples': 40, 'subsample': 0.9948339680796917, 'colsample_bytree': 0.6520208315013368, 'reg_alpha': 0.13247157882927973, 'reg_lambda': 7.3735400232473225}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:36:58,457] Trial 29 finished with value: 0.5147223928387552 and parameters: {'n_estimators': 598, 'learning_rate': 0.01804533380505444, 'num_leaves': 33, 'max_depth': 9, 'min_child_samples': 82, 'subsample': 0.6731391024666241, 'colsample_bytree': 0.6901875681464282, 'reg_alpha': 1.6387186150754545, 'reg_lambda': 0.0009896521776371486}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:37:05,454] Trial 30 finished with value: 0.5127391403377101 and parameters: {'n_estimators': 266, 'learning_rate': 0.03002266621401282, 'num_leaves': 88, 'max_depth': 8, 'min_child_samples': 164, 'subsample': 0.7165768423099347, 'colsample_bytree': 0.6309141837616339, 'reg_alpha': 2.7427699857037893, 'reg_lambda': 0.25188982152930867}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:37:15,946] Trial 31 finished with value: 0.5149246980194081 and parameters: {'n_estimators': 573, 'learning_rate': 0.01883327509886859, 'num_leaves': 34, 'max_depth': 9, 'min_child_samples': 83, 'subsample': 0.6690290400754281, 'colsample_bytree': 0.6944120995631999, 'reg_alpha': 1.5159884370786216, 'reg_lambda': 0.001719523926547521}. Best is trial 23 with value: 0.515140849293108.
# [I 2026-04-07 17:37:22,826] Trial 32 finished with value: 0.5151653044769714 and parameters: {'n_estimators': 341, 'learning_rate': 0.023771507185316287, 'num_leaves': 36, 'max_depth': 8, 'min_child_samples': 73, 'subsample': 0.6751355775917298, 'colsample_bytree': 0.678281575892165, 'reg_alpha': 9.768723014549156, 'reg_lambda': 1.1854837496806403e-05}. Best is trial 32 with value: 0.5151653044769714.
# [I 2026-04-07 17:37:30,817] Trial 33 finished with value: 0.5150745173586451 and parameters: {'n_estimators': 431, 'learning_rate': 0.020093194799892054, 'num_leaves': 26, 'max_depth': 8, 'min_child_samples': 69, 'subsample': 0.6604770672023038, 'colsample_bytree': 0.6909441501832841, 'reg_alpha': 4.7436223050218045, 'reg_lambda': 8.19409805936458e-05}. Best is trial 32 with value: 0.5151653044769714.
# [I 2026-04-07 17:37:39,337] Trial 34 finished with value: 0.5146070988913717 and parameters: {'n_estimators': 460, 'learning_rate': 0.02398916320082199, 'num_leaves': 25, 'max_depth': 7, 'min_child_samples': 70, 'subsample': 0.6575442623732736, 'colsample_bytree': 0.6981104206733213, 'reg_alpha': 9.778773360287481, 'reg_lambda': 2.4842641519077918e-05}. Best is trial 32 with value: 0.5151653044769714.
# [I 2026-04-07 17:37:49,877] Trial 35 finished with value: 0.5148979678759928 and parameters: {'n_estimators': 534, 'learning_rate': 0.014366435447856268, 'num_leaves': 28, 'max_depth': 6, 'min_child_samples': 57, 'subsample': 0.6197541660507057, 'colsample_bytree': 0.6362289461260308, 'reg_alpha': 0.2631526602756269, 'reg_lambda': 4.8983581037742116e-06}. Best is trial 32 with value: 0.5151653044769714.
# [I 2026-04-07 17:38:00,956] Trial 36 finished with value: 0.5138261605608854 and parameters: {'n_estimators': 600, 'learning_rate': 0.02007871096343169, 'num_leaves': 38, 'max_depth': 8, 'min_child_samples': 28, 'subsample': 0.684416640378798, 'colsample_bytree': 0.7306110125201851, 'reg_alpha': 0.9471146415590233, 'reg_lambda': 8.373583399884062e-05}. Best is trial 32 with value: 0.5151653044769714.
# [I 2026-04-07 17:38:12,498] Trial 37 finished with value: 0.5154583043916963 and parameters: {'n_estimators': 519, 'learning_rate': 0.012446486899992918, 'num_leaves': 66, 'max_depth': 7, 'min_child_samples': 82, 'subsample': 0.6390057791480404, 'colsample_bytree': 0.696630917243673, 'reg_alpha': 7.242254155714097, 'reg_lambda': 4.650719162235369e-06}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:38:21,623] Trial 38 finished with value: 0.5140949795520084 and parameters: {'n_estimators': 514, 'learning_rate': 0.011721716399431066, 'num_leaves': 69, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.6377833668017636, 'colsample_bytree': 0.7418592754743536, 'reg_alpha': 7.0142297155501065, 'reg_lambda': 5.228950792871581e-07}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:38:30,815] Trial 39 finished with value: 0.5020966957481582 and parameters: {'n_estimators': 431, 'learning_rate': 0.15968206803948826, 'num_leaves': 98, 'max_depth': 7, 'min_child_samples': 75, 'subsample': 0.7384790297854178, 'colsample_bytree': 0.6421878080027309, 'reg_alpha': 9.887771998347988, 'reg_lambda': 5.729722641117758e-06}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:38:38,932] Trial 40 finished with value: 0.5139266138599312 and parameters: {'n_estimators': 374, 'learning_rate': 0.01204552161653962, 'num_leaves': 53, 'max_depth': 6, 'min_child_samples': 49, 'subsample': 0.6005807490429349, 'colsample_bytree': 0.7131365869567531, 'reg_alpha': 0.36718693716055695, 'reg_lambda': 9.297139310347793e-05}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:38:51,440] Trial 41 finished with value: 0.51529577061921 and parameters: {'n_estimators': 553, 'learning_rate': 0.01527561869371824, 'num_leaves': 62, 'max_depth': 8, 'min_child_samples': 78, 'subsample': 0.6603860236529652, 'colsample_bytree': 0.6827190463739979, 'reg_alpha': 2.5239360468374556, 'reg_lambda': 1.506197217608482e-08}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:05,066] Trial 42 finished with value: 0.5150581825596383 and parameters: {'n_estimators': 504, 'learning_rate': 0.015276986294150158, 'num_leaves': 89, 'max_depth': 8, 'min_child_samples': 60, 'subsample': 0.6429666268146005, 'colsample_bytree': 0.6799479532703967, 'reg_alpha': 3.378033073494974, 'reg_lambda': 2.290547758785079e-08}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:19,293] Trial 43 finished with value: 0.514867764191325 and parameters: {'n_estimators': 562, 'learning_rate': 0.011057745492696712, 'num_leaves': 62, 'max_depth': 7, 'min_child_samples': 81, 'subsample': 0.6982298181116433, 'colsample_bytree': 0.6231950988522742, 'reg_alpha': 0.49543779443517866, 'reg_lambda': 2.0232711817181657e-07}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:29,827] Trial 44 finished with value: 0.5140478025318371 and parameters: {'n_estimators': 473, 'learning_rate': 0.021266768550760196, 'num_leaves': 62, 'max_depth': 8, 'min_child_samples': 73, 'subsample': 0.6265995415128405, 'colsample_bytree': 0.6583157608966494, 'reg_alpha': 3.426256250699581, 'reg_lambda': 7.1544925800394205e-06}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:39,101] Trial 45 finished with value: 0.5146580628915502 and parameters: {'n_estimators': 432, 'learning_rate': 0.013935063676221408, 'num_leaves': 50, 'max_depth': 7, 'min_child_samples': 114, 'subsample': 0.6567390160371546, 'colsample_bytree': 0.7086567226424073, 'reg_alpha': 1.3033500992689533, 'reg_lambda': 2.609856956269238e-06}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:47,096] Trial 46 finished with value: 0.5137051837640298 and parameters: {'n_estimators': 500, 'learning_rate': 0.024774871778352883, 'num_leaves': 21, 'max_depth': 8, 'min_child_samples': 88, 'subsample': 0.6865957792919177, 'colsample_bytree': 0.8284823216133199, 'reg_alpha': 0.08346083062286953, 'reg_lambda': 1.2811367443036628e-08}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:39:59,101] Trial 47 finished with value: 0.5144264134685732 and parameters: {'n_estimators': 547, 'learning_rate': 0.016444732137647945, 'num_leaves': 77, 'max_depth': 6, 'min_child_samples': 38, 'subsample': 0.7121102731107848, 'colsample_bytree': 0.755889043321974, 'reg_alpha': 0.3251953630033974, 'reg_lambda': 0.00019419922085863752}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:40:04,679] Trial 48 finished with value: 0.5126773799308044 and parameters: {'n_estimators': 357, 'learning_rate': 0.036465625533871546, 'num_leaves': 41, 'max_depth': 4, 'min_child_samples': 101, 'subsample': 0.7395606254133957, 'colsample_bytree': 0.7300825766757291, 'reg_alpha': 4.273758506151354e-08, 'reg_lambda': 1.7732172353447387e-05}. Best is trial 37 with value: 0.5154583043916963.
# [I 2026-04-07 17:40:11,420] Trial 49 finished with value: 0.5139881582522963 and parameters: {'n_estimators': 322, 'learning_rate': 0.010134962689117552, 'num_leaves': 29, 'max_depth': 7, 'min_child_samples': 57, 'subsample': 0.6734358274773955, 'colsample_bytree': 0.7086697127463879, 'reg_alpha': 4.219419463871826, 'reg_lambda': 7.247742030828739e-08}. Best is trial 37 with value: 0.5154583043916963.
# Best validation AUPRC: 0.5155
# LightGBM S-learner trained using best Optuna trial on full training data.

# %%
# Cell 4: Evaluate factual performance on test.csv
factual_proba = s_learner.predict_proba(X_test)[:, 1]
factual_pred = (factual_proba >= 0.5).astype(int)

precision = precision_score(y_test, factual_pred, zero_division=0)
recall = recall_score(y_test, factual_pred, zero_division=0)
accuracy = accuracy_score(y_test, factual_pred)
auprc = average_precision_score(y_test, factual_proba)

print("Test metrics on test.csv")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"Accuracy:  {accuracy:.4f}")
print(f"AUPRC:     {auprc:.4f}")
# Out:
# Test metrics on test.csv
# Precision: 0.6195
# Recall:    0.3136
# Accuracy:  0.9591
# AUPRC:     0.5116

# %%
# Cell 5: Counterfactual conversion predictions with treatment toggled
X_test_treated = X_test.copy()
X_test_control = X_test.copy()
X_test_treated[treatment_col] = 1
X_test_control[treatment_col] = 0

mu1 = s_learner.predict_proba(X_test_treated)[:, 1]  # P(conversion | do(treatment=1), x)
mu0 = s_learner.predict_proba(X_test_control)[:, 1]  # P(conversion | do(treatment=0), x)
uplift = mu1 - mu0

results = test_df.copy()
results["p_conversion_treated"] = mu1
results["p_conversion_control"] = mu0
results["uplift"] = uplift
results
# Out:
#                f0         f1        f2        f3         f4        f5  \
# 0       23.032518  10.059654  8.214383  4.679882  10.280525  4.115453
# 1       25.600311  10.059654  8.214383  4.679882  10.280525  4.115453
# 2       19.523195  10.059654  8.639891  3.359763  10.280525  4.115453
# 3       12.616365  10.059654  8.422836  4.679882  10.280525  4.115453
# 4       20.454730  10.059654  8.847605  3.907662  10.280525  4.115453
# ...           ...        ...       ...       ...        ...       ...
# 199995  12.616365  10.059654  9.040947  4.679882  10.280525  4.115453
# 199996  24.811454  10.059654  8.214383  4.679882  10.280525  4.115453
# 199997  22.928756  10.059654  8.378748  4.679882  10.280525  3.013064
# 199998  12.616365  10.059654  8.841462  4.679882  10.280525  4.115453
# 199999  15.527510  10.059654  8.536239 -1.163312  10.280525  4.115453
#
#                f6         f7        f8         f9       f10       f11  \
# 0      -12.422866   4.833815  3.971858  13.190056  5.300375 -0.168679
# 1       -1.288207   4.833815  3.971858  13.190056  5.300375 -0.168679
# 2       -7.301017   4.833815  3.878372  25.240993  5.300375 -0.168679
# 3        0.294443   4.833815  3.835851  18.380112  5.300375 -0.168679
# 4      -10.006574   4.833815  3.899112  13.190056  5.300375 -0.168679
# ...           ...        ...       ...        ...       ...       ...
# 199995   0.294443   4.833815  3.943716  13.190056  5.300375 -0.168679
# 199996  -1.288207   4.833815  3.971858  13.190056  5.300375 -0.168679
# 199997 -15.877431  11.560131  3.771810  46.672202  5.300375 -0.168679
# 199998   0.294443   4.833815  3.943716  13.190056  5.300375 -0.168679
# 199999 -12.028258   4.833815  3.943716  18.380112  5.300375 -0.168679
#
#         treatment  conversion  visit  exposure  p_conversion_treated  \
# 0               1           0      0         0              0.002210
# 1               1           0      0         0              0.000919
# 2               1           0      0         0              0.095395
# 3               1           0      0         0              0.191256
# 4               1           0      0         0              0.040305
# ...           ...         ...    ...       ...                   ...
# 199995          1           0      0         0              0.003829
# 199996          0           0      0         0              0.000823
# 199997          0           0      0         0              0.422458
# 199998          1           0      0         0              0.004694
# 199999          1           0      0         0              0.037570
#
#         p_conversion_control    uplift
# 0                   0.001532  0.000678
# 1                   0.000868  0.000051
# 2                   0.071093  0.024302
# 3                   0.184116  0.007140
# 4                   0.030019  0.010286
# ...                      ...       ...
# 199995              0.003773  0.000057
# 199996              0.000782  0.000041
# 199997              0.345376  0.077082
# 199998              0.004394  0.000300
# 199999              0.023221  0.014349
#
# [200000 rows x 19 columns]

# %%
# Cell 6: Save best S-learner model to PKL
import pickle

s_learner_bundle = {
    "model": s_learner,
    "feature_cols": feature_cols,
    "categorical_cols": categorical_cols,
    "treatment_col": treatment_col,
    "outcome_col": outcome_col,
    "best_params": best_params,
    "best_validation_auprc": study.best_value,
    "n_optuna_trials": 50,
}

with open("models/s_learner-visit.pkl", "wb") as f:
    pickle.dump(s_learner_bundle, f)

print("Saved best Optuna-tuned model: s_learner-visit.pkl")
# Out:
# Saved best Optuna-tuned model: s_learner-visit.pkl
